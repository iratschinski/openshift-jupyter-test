# %% [markdown]
# ## Data Generation
#
# In order to train a model to classify faults with metrobuses, we must first get our hands on some data. In this notebook we take a small data set, containing only 100 samples, and use [Markovify](https://github.com/jsvine/markovify) to simulate a larger data set, based on the original samples.
#
# We obtained a small data set by asking our colleagues to describe issues they currently have or had in the past, with their vehicles.
#
# **Note: you do not need to run this notebook in order to execute the remainder of the workshop. This notebook is solely for data generation. We have already generated the data for you, and it can be found in the `/dataset` folder.**
#
# Let's take a look at that data:

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
df = pd.read_csv('dataset/response.csv') 
df.sample(10)
# Out:
#                       Timestamp What is the main issue you're having   \
# 41    2021/03/04 1:19:59 PM CST                                 Other
# 77    2021/03/04 3:46:43 PM CST                                 Other
# 98   2021/03/05 12:22:23 PM CST                                 Other
# 17   2021/03/04 12:10:05 PM CST                                Brakes
# 53    2021/03/04 1:52:00 PM CST                               Starter
# 103  2021/03/05 12:28:42 PM CST                                Brakes
# 22   2021/03/04 12:34:25 PM CST                                 Other
# 56    2021/03/04 1:54:16 PM CST                                 Other
# 58    2021/03/04 1:56:11 PM CST                                Brakes
# 71    2021/03/04 2:28:34 PM CST                                 Other
#
#     Please pick one of these three symptoms:  \
# 41                                       NaN
# 77                                       NaN
# 98                                       NaN
# 17                                       NaN
# 53                    Car makes an odd noise
# 103                                      NaN
# 22                                       NaN
# 56                                       NaN
# 58                                       NaN
# 71                                       NaN
#
#     Please pretend you're a customer. In the space below tell us in your own words what's going wrong with your car:  \
# 41                                                                                                               NaN
# 77                                                                                                               NaN
# 98                                                                                                               NaN
# 17                                                                                                               NaN
# 53                                            It makes a grinding sound for a few seconds and then nothing happens.
# 103                                                                                                              NaN
# 22                                                                                                               NaN
# 56                                                                                                               NaN
# 58                                                                                                               NaN
# 71                                                                                                               NaN
#
#     Please pick one of these three symptoms:.1  \
# 41                                         NaN
# 77                                         NaN
# 98                                         NaN
# 17                    Car makes grinding noise
# 53                                         NaN
# 103          Car doesn't stop in timely manner
# 22                                         NaN
# 56                                         NaN
# 58                    Car makes grinding noise
# 71                                         NaN
#
#                               Please pretend you're a customer. In the space below tell us in your own words what's going wrong with your car:.1  \
# 41                                                                                                                                           NaN
# 77                                                                                                                                           NaN
# 98                                                                                                                                           NaN
# 17   It was really cold out and I could not get the emergency brake to disengage. When I tried to drive, the car made horrible grinding noises.
# 53                                                                                                                                           NaN
# 103                                                                                                                         my car does not stop
# 22                                                                                                                                           NaN
# 56                                                                                                                                           NaN
# 58                             The brake squeak and any time the slightest pressure is applied to the brake pedal.  And the brake pedal vibrates
# 71                                                                                                                                           NaN
#
#                                                                                                                                                                                                  Please pretend you're a customer. In the space below tell us in your own words what's going wrong with your car:.2
# 41                                                                                                                                                                                                                                              I'm hearing a noise and feeling a vibration when I turn the wheel.
# 77                                                                                                                                                                                                                                                             I hear a rattling noise when i drive it above 60 mph
# 98                                                                                            My battery keeps dying.  This is the third one, and I don't get it.  I turn the radio and a/c off, trying to use as little power as possible, and the batteries just keep dying after about a week.  Aaarrrggghhh!!!!
# 17                                                                                                                                                                                                                                                                                                              NaN
# 53                                                                                                                                                                                                                                                                                                              NaN
# 103                                                                                                                                                                                                                                                                                                             NaN
# 22                                                                                                                                                                                                      When it rains, the car slides under braking and specially slips when driving over painted lines on the road
# 56   When I put the car in reverse, the hatchback latch opens so that the backup camera can engage. That's all good. But sometimes, the latch stays permanently opened while I'm driving and when I stop and park, I cannot open the hatchback due to the latch being stuck in the open position (but not engaged).
# 58                                                                                                                                                                                                                                                                                                              NaN
# 71                                                                                                                                                                                                                                                                  It makes clunking noises when I go over a bump.

# %% [markdown]
# As you can see, the data contains a range of information including, the time the error was recorded, and the type of issue, as well as a description of the problem. The information we are really interested in is the type of issue, and the description - let's go ahead and process this data, extracting only the info we need!

# %%
df = df.fillna('')
df['response']=df.iloc[:,3]+df.iloc[:,5]+df.iloc[:,6]
df['issue'] = df.iloc[:,1]
df['symptom'] = df.iloc[:,2] + df.iloc[:,4]
subset = df.iloc[:,-3:]
subset.sample(10)
# Out:
#                                                                                                                                                                                                                                                                                                            response  \
# 77                                                                                                                                                                                                                                                             I hear a rattling noise when i drive it above 60 mph
# 33                      Sometimes the car doesn't start and it seems like the battery is dead, but I have replaced the battery three times over the past year, so I think maybe either I'm buying defective batteries or something about the car is wrecking perfectly good batteries that should be lasting years.
# 61                                                                                                                                                                                                                                              Leak of a clear, cloudy, oil like substance in the back of the car.
# 49                                                                                                                                                                                                                                                           Car creates whistle sound each time I try to start it.
# 43                                                                                                                                                                                                                                   There is a lag when I push the gas peddle. There isn't an immediate response.
# 105                                                                                                                                                                                                                                                                                           my lights do not work
# 88                                                                                                                                                                                                                                        I have to press the ignition button at least twice before my car starts.
# 56   When I put the car in reverse, the hatchback latch opens so that the backup camera can engage. That's all good. But sometimes, the latch stays permanently opened while I'm driving and when I stop and park, I cannot open the hatchback due to the latch being stuck in the open position (but not engaged).
# 62                                                                                                                                                                                                                                                                   Front right corner is dented from a collision.
# 90                                                                                                                                                                                                    the privacy glass between my driver and my seating area doesn't work well.  sometimes, it won't go up at all!
#
#        issue                 symptom
# 77     Other
# 33   Starter       Car doesn't start
# 61     Other
# 49   Starter  Car makes an odd noise
# 43     Other
# 105    Other
# 88   Starter   Car starts then stops
# 56     Other
# 62     Other
# 90     Other

# %% [markdown]
# This looks much nicer! Let's explore our data:

# %%
subset.issue.unique()
# Out:
# array(['Brakes', 'Starter', 'Other'], dtype=object)

# %% [markdown]
# We only have 3 categories of issue - 'Brakes', 'Starter' and 'Other'.
#
# How much data do we have?

# %%
subset.shape
# Out:
# (109, 3)

# %%
subset['issue'].value_counts()
# Out:
# Other      56
# Brakes     28
# Starter    25
# Name: issue, dtype: int64

# %% [markdown]
# Only 109 rows - That's not likely to be enough to train a successful categorization model.
#
# Most of the data falls into the 'other' category.

# %% [markdown]
# In the rest of this notebook, we use Markovify to generate more data for each class of issue. Markovify is a Markov Chain generator, and we are going to use it to simulate more responses for each type of issue.
#
# First we install markovify, which is in our `nb-requirements.txt` file:

# %%
# !pip install -r nb-requirements.txt
# Out:
# Collecting markovify==0.9.3
#   Downloading markovify-0.9.3.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tensorflow==2.7.0
#   Downloading tensorflow-2.7.0-cp38-cp38-manylinux2010_x86_64.whl (489.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.6/489.6 MB 258.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scikit-learn==0.24.1 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 3)) (0.24.1)
# Requirement already satisfied: numpy==1.19.2 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 4)) (1.19.2)
# Requirement already satisfied: pandas==1.2.4 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 5)) (1.2.4)
# Requirement already satisfied: keras==2.7.0 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 6)) (2.7.0)
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 285.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.48.0rc1)
# Requirement already satisfied: absl-py>=0.4.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.12.1)
# Requirement already satisfied: libclang>=9.0.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (14.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.26.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (4.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: tensorboard~=2.6 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (3.20.1)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r nb-requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r nb-requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r nb-requirements.txt (line 3)) (1.6.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas==1.2.4->-r nb-requirements.txt (line 5)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/app-root/lib/python3.8/site-packages (from pandas==1.2.4->-r nb-requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (3.3.7)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2.2.0a1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (63.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/app-root/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (4.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (1.26.10)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/app-root/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/app-root/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0->-r nb-requirements.txt (line 2)) (3.2.0)
# Building wheels for collected packages: markovify
#   Building wheel for markovify (setup.py) ... done
#   Created wheel for markovify: filename=markovify-0.9.3-py3-none-any.whl size=18596 sha256=948ab65a7dfe4a0977130776657d2bd1702a29d2b9baf6bcde3b5cad356fb9cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fui8gtgw/wheels/14/aa/cc/2ed670f560efe25f80cbc90ad0220e80e4893ccf72f8099ec7
# Successfully built markovify
# Installing collected packages: unidecode, markovify, tensorflow
# Successfully installed markovify-0.9.3 tensorflow-2.7.0 unidecode-1.3.6

# %%
import markovify
import csv

# %%
def train_markov_type(data, issue):
    return markovify.Text(data[data["issue"] == issue].response, retain_original=False, state_size=2)

#Function takes one of the 'issue' models and creates a randomly-generated sentence of length up to 100 characters.  
def make_sentence(model, length=100):
    return model.make_short_sentence(length, max_overlap_ratio = .7, max_overlap_total=15)

#built models
other_model = train_markov_type(subset, "Other")
brakes_model = train_markov_type(subset, "Brakes")
starter_model = train_markov_type(subset, "Starter")

# %% [markdown]
# We can combine these models with relative weights:

# %%
import numpy

def generate_cases(models, weights=None):
    if weights is None:
        weights = [1] * len(models)
    
    choices = [] # Array of tuples of weight and models
    
    total_weight = float(sum(weights))
    
    for i in range(len(weights)):
        choices.append((float(sum(weights[0:i+1])) / total_weight, models[i]))
    
    # Return a tuple of model and category that are randomly selected by given weights.
    def choose_model():
        r = numpy.random.uniform()
        for (model_weight, model) in choices:
            if r <= model_weight:
                return model
        return choices[-1][1]


    while True:
        local_model = choose_model() 
        # local_model[0]) is the markovify model, local_model[1] is the category
        yield make_sentence(local_model[0]), local_model[1]

# %% [markdown]
# We can now use this code to generate new sentences:

# %%
import numpy as np

generated_cases = generate_cases([(other_model,'other'), (brakes_model,'brakes'), (starter_model,'starter')], [14,7,7])

# Tuples with sentence and category
sentence_tuples = [next(generated_cases)  for i in range(1000)]  # create 200 sentence/category tuples

# %%
sentence_tuples
# Out:
# [('The paint on the fuel line, and apparently it came loose while driving.',
#   'other'),
#  ('The car pulls to the air bag or seat belt.', 'other'),
#  ('Car dies when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ("AC doesn't work well.", 'other'),
#  ('I have some noise when I open my rear trunk', 'other'),
#  ("I can't get up to 88 MPH", 'other'),
#  ("The car won't turn on, but it won't go up at all!", 'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('My cars breaks make a squeaking noise whenever I try to stop when I press down',
#   'brakes'),
#  ('My cars breaks make a terrible sound when stopping.', 'brakes'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('I think my car is behaving very weird.', 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ("It won't go, but it won't go up at all!", 'other'),
#  ("I don't get it.", 'other'),
#  ('The car pulls to the left.', 'other'),
#  ('Alternator is faulty', 'starter'),
#  ('Then I have to brake again.', 'brakes'),
#  ('That is all', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('When I drive, I feel like the car is leaning on left', 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("the flux capacitor is misfiring and I can't put gas in my steering wheel.",
#   'other'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('There is a bit short these days.', 'other'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('My car is very unsafe.', 'other'),
#  ("I'm not sure if it is the battery since the lights and radio worked but it doesn't work.",
#   'starter'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('My car is now a pile of ashes.', 'other'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ("Where's the place, where I need to insert my key to start it.", 'starter'),
#  ('Car creates whistle sound each time I start my car it just stops again, what is wrong!',
#   'starter'),
#  ('My car is leaning on left', 'other'),
#  ('68F', 'other'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ("My window won't roll up.", 'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('When it rains, the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('my car does not stop', 'brakes'),
#  ('When I try to start the engine unless you hit the starter with a hammer.',
#   'starter'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ('The seat belt itself on the freeway.', 'other'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('Car does not turn over.', 'starter'),
#  ('The other 3 tires report normally.', 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ("I'm not sure if it is the battery since the lights would come one and the car doesnt start.",
#   'starter'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('my brakes make a squeaking noise whenever I try to stop the car.',
#   'brakes'),
#  ('Steering wheel shakes uncontrollably when I go over a bump.', 'other'),
#  ('When I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ("The car won't turn on, but it won't turn on, but it won't go up at all!",
#   'other'),
#  ("It's an intense upper body workout to stay in one lane on the road",
#   'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ("When I drive, I feel like the car won't turn on, but it won't turn off either.",
#   'other'),
#  ('Cannot get the car would not start.', 'starter'),
#  ('My car does not start.', 'starter'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ("The steering wheel shudders and I can't put gas in my car if the control says, eg.",
#   'other'),
#  ('My tire keeps going flat.', 'other'),
#  ('This is the third one, and I hear a grinding noise as I drive.', 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('Cannot get the car would make a click click clicking sound - maybe a dead battery?',
#   'starter'),
#  ('Car does not turn over.', 'starter'),
#  ('My car does not turn over.', 'starter'),
#  ('The paint on the left door is scratched.', 'other'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('Metallic scraping or grinding noise when breaking.', 'brakes'),
#  ("There isn't an immediate response.", 'other'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ("My air conditioning doesn't seem to be something related to the left.",
#   'other'),
#  ('Shuttering when accelerating', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('the flux capacitor is misfiring and I hear a rattling noise when i drive it above 60 mph',
#   'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('Car does not turn over', 'starter'),
#  ('My car sounds like its 20 years old when I push hard on the brake pedal.',
#   'brakes'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ("Car dies when I stop at a light or stop sign and then won't start again.",
#   'starter'),
#  ('Car creates whistle sound each time I try to start it.', 'starter'),
#  ("Starter makes clicking noise, won't start the ignition?", 'starter'),
#  ('Please help ASAP!', 'starter'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('68F', 'other'),
#  ('Car makes a grinding noise and brakes disengage', 'brakes'),
#  ("I'm not sure if it is the battery three times before the car would not start.",
#   'starter'),
#  ("That's all good.", 'other'),
#  ("I'm on the fuel line, and apparently it came loose while driving.",
#   'other'),
#  ("The gas door won't open.", 'other'),
#  ("It sputters for a few seconds and then won't start again.", 'starter'),
#  ('I press on the brake pedal', 'brakes'),
#  ('I tried starting my car starts.', 'starter'),
#  ('Customer states breaks make noises and also take more time to come to a complete stop.',
#   'brakes'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ("The car won't turn off either.", 'other'),
#  ("I can't put gas in my steering wheel.", 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('That is all', 'other'),
#  ('My tire keeps going flat.', 'other'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('Sometimes when I push hard on the brake pedal.', 'brakes'),
#  ('While driving I hear lot of grinding and scraping noises when I try to stop',
#   'brakes'),
#  ('Metallic scraping or grinding noise when stopping.', 'brakes'),
#  ('I have some noise when I go over a bump.', 'other'),
#  ('I have to press the ignition button at least twice before my car starts.',
#   'starter'),
#  ('Car takes too long to stop when I try to stop and sometimes very bumpy.',
#   'brakes'),
#  ('I hear a rattling noise when I bought the car.', 'other'),
#  ('It sputters for a very long time to start, and if I push the key in it makes a grinding noise too.',
#   'starter'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('Customer states breaks make a deep grinding metal sound', 'brakes'),
#  ("I have the car won't start!", 'other'),
#  ('The HVAC system is broken in the front.', 'other'),
#  ('my lights do not work', 'other'),
#  ('Car does not turn over.', 'starter'),
#  ('I keep my foot firmly pressing down on the brakes.', 'brakes'),
#  ("I can't put gas in my car if the door won't open, and I'm all out of gas.",
#   'other'),
#  ('It then takes several clicks on the side of the car.', 'other'),
#  ('super frustrating every time I start it', 'starter'),
#  ('Car does not turn over.', 'starter'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('The steering wheel shakes when running at speed', 'other'),
#  ("I'm not sure if it is the battery since the lights and radio worked but it doesn't work.",
#   'starter'),
#  ('Car does not start.', 'starter'),
#  ('The pedal feels squishy and pulses when I push hard on the brakes.',
#   'brakes'),
#  ('The oil change has been performed.', 'other'),
#  ('I think my car if the control says, eg.', 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('68F', 'other'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('The car is now a pile of ashes.', 'other'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ('I keep driving past my driveway because the car refuses to stop when I push hard on the brakes.',
#   'brakes'),
#  ('I press the brakes disengage.', 'brakes'),
#  ("The car won't shift out of gas.", 'other'),
#  ('There is a bit short these days.', 'other'),
#  ('The warning indicator light is out.', 'other'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('Car takes too long to stop', 'brakes'),
#  ('The pedal feels squishy and pulses when I try to stop', 'brakes'),
#  ("I tried starting my car but it doesn't work.", 'starter'),
#  ("sometimes, it won't turn off either.", 'other'),
#  ('The battery is getting old so my range is a lag when I manually check it, it is fine.',
#   'other'),
#  ('Car takes too long to stop when I press the brakes', 'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ('I turn the wheel.', 'other'),
#  ('Alternator is faulty', 'starter'),
#  ('I turn the key, nothing happens.', 'other'),
#  ('I have some noise when I turn the key, nothing happens.', 'other'),
#  ('I think my alignment is bad.', 'other'),
#  ("The car won't start!", 'other'),
#  ('I have a keyless start system and when I step on the the fourth time.',
#   'starter'),
#  ("That's all good.", 'other'),
#  ('If I try to set it at anything other than MAX COOL, it defaults to full blast cooling.',
#   'other'),
#  ('It takes a long time before finally engaging and actually turning on.',
#   'starter'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('The car make some squeaking noises when I brake, after a few seconds, the brakes',
#   'brakes'),
#  ('The car pulls to the air bag or seat belt.', 'other'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('I tried starting my car it just stops again, what is wrong!', 'starter'),
#  ('It is very unpleasant.', 'brakes'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('Cannot get the car doesnt start.', 'starter'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('Car creates whistle sound each time I start it', 'starter'),
#  ('When I put the car does not feel secure.', 'other'),
#  ('I tried starting my car starts.', 'starter'),
#  ("the flux capacitor is misfiring and I don't get it.", 'other'),
#  ('The battery is getting old so my range is a lag when I accelerate above 60 mph',
#   'other'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ('Shuttering when accelerating', 'other'),
#  ('My cars breaks make a deep grinding metal sound', 'brakes'),
#  ('My car does not turn over', 'starter'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('The car is making a clicking noise.', 'other'),
#  ('Car does not turn over', 'starter'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Then I have to brake the car does not stop', 'brakes'),
#  ('I have some noise when i drive it above 60 mph.', 'other'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ("The car won't start!", 'other'),
#  ("The gas door won't open, and I'm all out of park.", 'other'),
#  ('That is all', 'other'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ('I have the button pushed in and the fan is running full blast.', 'other'),
#  ('It makes clunking noises when I manually check it, it is fine.', 'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('My car is behaving very weird.', 'other'),
#  ("My car is very slow to get moving and there's a horrible grinding noise as I drive.",
#   'other'),
#  ('When it rains, the car is now a pile of ashes.', 'other'),
#  ('I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('My car does not turn over.', 'starter'),
#  ('I turn the key in it makes a sputtering noise and does not turn over.',
#   'starter'),
#  ("I don't get it.", 'other'),
#  ('Squealing sound', 'brakes'),
#  ('My car is leaning on left', 'other'),
#  ('My car sounds like its 20 years old when I press on the brake pedal.',
#   'brakes'),
#  ('It makes a grinding noise too.', 'starter'),
#  ("The car won't start!", 'other'),
#  ('I turn the key in it makes a sputtering noise and does not start.',
#   'starter'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ("the flux capacitor is misfiring and I can't put gas in my steering wheel.",
#   'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('I came out from work at the end of the day and the car would not start.',
#   'starter'),
#  ('It makes a weird whirring sound every time I start it', 'starter'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ('super frustrating every time I start my car starts.', 'starter'),
#  ('I can hear the starter firing but the car to turn over.', 'starter'),
#  ('My battery keeps dying.', 'other'),
#  ('Then I have to press the brake and the car made horrible grinding noises.',
#   'brakes'),
#  ('Squealing sound', 'brakes'),
#  ("This is the third one, and I can't open the damn door to my previous display which is very unsafe.",
#   'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('My cars breaks make a squeaking noise whenever I try to stop', 'brakes'),
#  ('My car drifts when driving it and my tires seem to be working.', 'other'),
#  ('It makes a sputtering noise and does not start.', 'starter'),
#  ("sometimes, it won't turn on, but it won't turn off either.", 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ("The gas door won't open, and I'm all out of park.", 'other'),
#  ('When I put the car is behaving very weird.', 'other'),
#  ("AC doesn't work well.", 'other'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('It sputters for a while and never turns over.', 'starter'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('Cannot get the car to turn over.', 'starter'),
#  ('Car takes too long to stop', 'brakes'),
#  ('My car is leaning on left', 'other'),
#  ('It seems like I have to brake again.', 'brakes'),
#  ('I press the brake pedal.', 'brakes'),
#  ('Alternator is faulty', 'starter'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ('The steering wheel shakes when running at speed', 'other'),
#  ('I tried starting my car starts.', 'starter'),
#  ('It makes a weird whirring sound every time I start my car it just stops again, what is wrong!',
#   'starter'),
#  ('My car does not start.', 'starter'),
#  ('The seat belt itself on the left door is scratched.', 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ("AC doesn't work", 'other'),
#  ('My car is leaning on left', 'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ("the privacy glass between my driver and my seating area doesn't work well.",
#   'other'),
#  ('The steering wheel shudders and I hear a rattling noise when i drive it above 60 mph.',
#   'other'),
#  ('Not so much a grinding noise', 'brakes'),
#  ('When I try to start it.', 'starter'),
#  ('The oil change light comes on after an oil change light comes on and the air bag or seat belt.',
#   'other'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ("The car won't turn off either.", 'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ("The gas door won't open, and I'm all out of gas.", 'other'),
#  ('car makes grinding noise', 'brakes'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('Squealing sound', 'brakes'),
#  ('I think my alignment is bad.', 'other'),
#  ('Sometimes when I press the brakes disengage.', 'brakes'),
#  ('Car takes too long to stop the car.', 'brakes'),
#  ("I'm hearing a noise and feeling a vibration when I accelerate above 60 mph.",
#   'other'),
#  ('When I tried to drive, the car does not stop', 'brakes'),
#  ('Plus it seems it takes more force to stop and sometimes very bumpy.',
#   'brakes'),
#  ('And the brake pedal.', 'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ('My car makes a sputtering noise and does not start.', 'starter'),
#  ('I keep my foot firmly pressing down on the brake and the car', 'brakes'),
#  ('68F', 'other'),
#  ('Car creates whistle sound each time I try to start it.', 'starter'),
#  ('This is the third one, and I hear a rattling noise when i drive it above 60 mph.',
#   'other'),
#  ('My battery keeps dying.', 'other'),
#  ('It takes a long time to start, and if I push the key and hear funny sounds but nothing happens.',
#   'starter'),
#  ('It is very unpleasant.', 'brakes'),
#  ("AC doesn't work", 'other'),
#  ('windshield wipers', 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('I turn the key and nothing happens', 'starter'),
#  ("I'm on the freeway.", 'other'),
#  ('68F', 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('My car drifts when driving over painted lines on the freeway.', 'other'),
#  ('Rear right tail light is out.', 'other'),
#  ('Shuttering when accelerating', 'other'),
#  ('My car is now a pile of ashes.', 'other'),
#  ('The pedal feels squishy and pulses when I press on the brake pedal',
#   'brakes'),
#  ("When turning, the car won't start!", 'other'),
#  ('My tire keeps going flat.', 'other'),
#  ('While driving I hear lot of grinding and scraping noises when I press on the brake and the car',
#   'brakes'),
#  ("My window won't roll up.", 'other'),
#  ('It seems like I have to brake the car does not stop', 'brakes'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('Sometimes the car doesnt start.', 'starter'),
#  ('Sometimes the car would make a click click clicking sound but would not start.',
#   'starter'),
#  ('I try to start the engine doesn’t power up', 'starter'),
#  ('The oil change light comes on after an oil change has been performed.',
#   'other'),
#  ('The car is making a clicking noise.', 'other'),
#  ('super frustrating every time I start it', 'starter'),
#  ("I have to press the ignition button at least twice before my car but it doesn't work.",
#   'starter'),
#  ('car makes grinding noise', 'brakes'),
#  ("My air conditioning doesn't seem to be working.", 'other'),
#  ('It makes a grinding noise too.', 'starter'),
#  ('The battery is getting old so my range is a lag when I accelerate above 60 mph',
#   'other'),
#  ("the privacy glass between my driver and my seating area doesn't work",
#   'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('I have to press the ignition three times before the car doesnt start.',
#   'starter'),
#  ("I'm on the side of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ('My car makes a grinding noise too.', 'starter'),
#  ('It is very unpleasant.', 'brakes'),
#  ('Shuttering when accelerating', 'other'),
#  ('Car won’t stop quickly', 'brakes'),
#  ("I'm hearing a noise and feeling a vibration when I turn the key, nothing happens.",
#   'other'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ("I can't put gas in my car", 'other'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ("It sputters for a few seconds and then won't start again.", 'starter'),
#  ('There is a light that came on that looks to be working.', 'other'),
#  ('And the brake and the car refuses to stop', 'brakes'),
#  ("The car won't start!", 'other'),
#  ('The oil change has been performed.', 'other'),
#  ('my brakes make a terrible sound when stopping.', 'brakes'),
#  ('I came out from work at the end of the day and the car doesnt start.',
#   'starter'),
#  ('My car makes a weird whirring sound every time I start it', 'starter'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('It seems like I have to press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('I hear a rattling noise when i drive it above 60 mph', 'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('The car make some squeaking noises when I try to stop', 'brakes'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ("the flux capacitor is misfiring and I can't get up to 88 MPH", 'other'),
#  ("It's an intense upper body workout to stay in one lane on the freeway.",
#   'other'),
#  ('I came out from work at the end of the day and the car doesnt start.',
#   'starter'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('I tried starting my car starts.', 'starter'),
#  ('Cannot get the car to turn over.', 'starter'),
#  ("That's all good.", 'other'),
#  ('The pedal feels squishy and pulses when I push hard on the brakes.',
#   'brakes'),
#  ('When coming to a stop light, I press down', 'brakes'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('I have a keyless start system and when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ("There isn't an immediate response.", 'other'),
#  ('My car does not start.', 'starter'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ("I'm hearing a noise and feeling a vibration when I turn the key, nothing happens.",
#   'other'),
#  ('There is a bit short these days.', 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ("The gas door won't open, and I'm all out of park.", 'other'),
#  ("I'm on the left door is scratched.", 'other'),
#  ('Metallic scraping or grinding noise', 'brakes'),
#  ("Where's the place, where I need to insert my key to start the engine doesn’t power up",
#   'starter'),
#  ("AC doesn't work well.", 'other'),
#  ('The oil change has been performed.', 'other'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('When I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ('When I try to start the ignition?', 'starter'),
#  ('The car pulls to the air coming out of gas.', 'other'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ('my lights do not work', 'other'),
#  ('I press on the brake pedal.', 'brakes'),
#  ('The HVAC system is broken in the back of the car.', 'other'),
#  ('I was working on the passenger front side is having issues and does not roll back up.',
#   'other'),
#  ('The other 3 tires report normally.', 'other'),
#  ('The warning indicator light is on, which means I need to have the car does not roll back up.',
#   'other'),
#  ('It makes clunking noises when I accelerate above 60 mph', 'other'),
#  ("I'm on the road", 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('I turn the key in the ignition, I just get a clicking sound but would not start.',
#   'starter'),
#  ('Rear right tail light is on, which means I need to have the car evaluated.',
#   'other'),
#  ("The car won't turn off either.", 'other'),
#  ('Squealing sound', 'brakes'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('The car make some squeaking noises when I try to stop', 'brakes'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('Please help ASAP!', 'starter'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('If I try to set it at anything other than MAX COOL, it defaults to full blast cooling.',
#   'other'),
#  ('Steering wheel shakes uncontrollably when I manually check it, it is fine.',
#   'other'),
#  ("Everything seems to be working ok, but that sound wasn't there when I bought the car.",
#   'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('Squealing sound', 'brakes'),
#  ('I was working on the fuel line, and apparently it came loose while driving.',
#   'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('It makes clunking noises when I push the gas peddle.', 'other'),
#  ('The oil change light comes on and the air coming out of gas.', 'other'),
#  ('When I drive, I feel like the car evaluated.', 'other'),
#  ('There a loud knocking sound coming from somewhere in the front.', 'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('That is all', 'other'),
#  ('Customer states breaks make noises and also take more time to stop.',
#   'brakes'),
#  ('car makes grinding noise', 'brakes'),
#  ("There isn't an immediate response.", 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ('windshield wipers', 'other'),
#  ('68F', 'other'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('Squealing sound', 'brakes'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('My car does not turn over.', 'starter'),
#  ('I think my car is leaning on left', 'other'),
#  ('windshield wipers', 'other'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Squealing sound', 'brakes'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('Plus it seems it takes a long time to come to a stop light, I press on the brake pedal.',
#   'brakes'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ('The pedal feels squishy and pulses when I try to stop the car.', 'brakes'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('It then takes several clicks on the road', 'other'),
#  ('When I turn the key and nothing happens', 'starter'),
#  ('my brakes make a squeaking noise whenever I try to stop the car.',
#   'brakes'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('Shuttering when accelerating', 'other'),
#  ("The gas door won't open, and I'm all out of gas.", 'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ("Starter makes clicking noise, won't start the engine doesn’t power up",
#   'starter'),
#  ('windshield wipers', 'other'),
#  ('I have some noise when i drive it above 60 mph', 'other'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('My car makes a grinding sound for a while and never turns over.',
#   'starter'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('super frustrating every time I start my car starts.', 'starter'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ("My air conditioning doesn't seem to be something related to the left.",
#   'other'),
#  ("That's all good.", 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ('I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('I have to press the ignition three times before the car would not start.',
#   'starter'),
#  ("The gas door won't open, and I'm all out of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ('The steering wheel shakes when running at speed', 'other'),
#  ('The pedal feels squishy and pulses when I try to brake again.', 'brakes'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ("the privacy glass between my driver and my seating area doesn't work well.",
#   'other'),
#  ('My car is leaning on left', 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ('I have the button pushed in and the batteries just keep dying after about a week.',
#   'other'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ('I think my car if the control says, eg.', 'other'),
#  ('It makes a weird whirring sound every time I try to start the ignition?',
#   'starter'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('my car does not stop', 'brakes'),
#  ('My car is very unsafe.', 'other'),
#  ('It seems like I have to press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ('Metallic scraping or grinding noise when stopping.', 'brakes'),
#  ('I have a keyless start system and when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ('Plus it seems it takes a long time to stop.', 'brakes'),
#  ('Sometimes the car is wrecking perfectly good batteries that should be lasting years.',
#   'starter'),
#  ('When I try to start the ignition?', 'starter'),
#  ('my car does slow, but it takes a long time to stop.', 'brakes'),
#  ('Car won’t stop quickly', 'brakes'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('68F', 'other'),
#  ('Plus it seems it takes more force to stop when I brake, after a few seconds, the brakes',
#   'brakes'),
#  ('My cars breaks make a terrible sound when stopping.', 'brakes'),
#  ('68F', 'other'),
#  ("AC doesn't work well.", 'other'),
#  ('Car makes a grinding noise when stopping.', 'brakes'),
#  ("It won't start the engine only to find that the dashboard lights up, but the car to turn over.",
#   'starter'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('I have the button pushed in and the batteries just keep dying after about a week.',
#   'other'),
#  ('It makes a sputtering noise and does not turn over.', 'starter'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('When I drive, I feel like the car does not roll back up.', 'other'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('My cars breaks make noises and also take more time to come to a stop light, I press on the brakes.',
#   'brakes'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ("Car dies when I stop at a light or stop sign and then won't start again.",
#   'starter'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ("I can't open the damn door to my car", 'other'),
#  ('super frustrating every time I try to start the ignition?', 'starter'),
#  ('Brake pedal vibrates or feels unsteady as you press down on the brake pedal.',
#   'brakes'),
#  ("There isn't an immediate response.", 'other'),
#  ('But the car is talking to me through the radio and asking me if I know where the All Spark is hidden',
#   'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('Not so much a grinding noise when stopping.', 'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('Car takes too long to stop the car.', 'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('I turn the key, nothing happens.', 'other'),
#  ('It seems like I have to brake the car refuses to stop when I try to brake again.',
#   'brakes'),
#  ('There is a light that came on that looks to be wearing down at different rates.',
#   'other'),
#  ('Then I have to press the brakes', 'brakes'),
#  ('Usefulness is vanishing...', 'other'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('I turn the key in the ignition, I just get a clicking sound but would not start.',
#   'starter'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('The car pulls to the air coming out of gas.', 'other'),
#  ("It's an intense upper body workout to stay in one lane on the road",
#   'other'),
#  ('I keep driving past my driveway because the car does slow, but it takes more force to stop',
#   'brakes'),
#  ('That is all', 'other'),
#  ("I'm not sure if it is the battery since the lights and radio worked but it doesn't work.",
#   'starter'),
#  ("This is the third one, and I can't get up to 88 MPH", 'other'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ("My window won't roll up.", 'other'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ("The car won't shift out of park.", 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down on the brakes.',
#   'brakes'),
#  ("This is the third one, and I don't get it.", 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('My car makes a sputtering noise and does not turn over.', 'starter'),
#  ('There is a bit short these days.', 'other'),
#  ('my car does not stop', 'brakes'),
#  ('Shuttering when accelerating', 'other'),
#  ('When coming to a stop at a stop at a stop at a stop at a stop light, I press down',
#   'brakes'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('I think my alignment is bad.', 'other'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('Sometimes the car to turn over.', 'starter'),
#  ('The HVAC system is broken in the car.', 'other'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('Car takes too long to stop when I push hard on the brake pedal', 'brakes'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('I turn the key in the ignition, I just get a clicking sound but would not start.',
#   'starter'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('There a loud knocking sound coming from the front of the car.', 'other'),
#  ('Steering wheel shakes uncontrollably when I bought the car.', 'other'),
#  ("My car drifts when driving it and my seating area doesn't work well.",
#   'other'),
#  ('Rear right tail light is out.', 'other'),
#  ('Leak of a clear, cloudy, oil like substance in the car.', 'other'),
#  ('The car pulls to the air bag or seat belt.', 'other'),
#  ('I tried starting my car it just stops again, what is wrong!', 'starter'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('When I drive, I feel like the car does not feel secure.', 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('The car pulls to the left.', 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ("It's an intense upper body workout to stay in one lane on the left door is scratched.",
#   'other'),
#  ('When I tried to drive, the car', 'brakes'),
#  ('And the brake pedal', 'brakes'),
#  ("I don't get it.", 'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('I hear a grinding noise as I drive.', 'other'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('My car does not start.', 'starter'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('Sometimes when I try to stop the car.', 'brakes'),
#  ('When I turn the key and nothing happens', 'starter'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('It sputters for a very long time to start, and if I push the key in it makes a grinding noise too.',
#   'starter'),
#  ('Car makes a grinding noise', 'brakes'),
#  ("the flux capacitor is misfiring and I don't get it.", 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('I have to press the ignition button at least twice before my car it just stops again, what is wrong!',
#   'starter'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ("It won't start and doesn't respond when trying to jump start it.",
#   'starter'),
#  ("I can't put gas in my steering wheel.", 'other'),
#  ("the flux capacitor is misfiring and I don't get it.", 'other'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('Cannot get the car doesnt start.', 'starter'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ("Have to cycle the ignition button at least twice before my car but it doesn't work.",
#   'starter'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('Car takes too long to stop when I try to stop', 'brakes'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ('Have to cycle the ignition button at least twice before my car but it definitely was not starting.',
#   'starter'),
#  ('I have to press the ignition three times before the car doesnt start.',
#   'starter'),
#  ("the flux capacitor is misfiring and I can't open the damn door to my car",
#   'other'),
#  ('The HVAC system is broken in the front.', 'other'),
#  ('Car does not start.', 'starter'),
#  ('But the car does not feel secure.', 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('I have a keyless start system and when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('I was working on the fuel line, and apparently it came loose while driving.',
#   'other'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ('The car is talking to me through the radio and asking me if I know where the All Spark is hidden',
#   'other'),
#  ('Please help ASAP!', 'starter'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('My tire keeps going flat.', 'other'),
#  ('Car takes too long to stop the car.', 'brakes'),
#  ("When it rains, the car won't start!", 'other'),
#  ('It seems like I have to press the brakes', 'brakes'),
#  ('Usefulness is vanishing...', 'other'),
#  ('my lights do not work', 'other'),
#  ('Cannot get the car doesnt start.', 'starter'),
#  ('If I try to set it at anything other than MAX COOL, it defaults to full blast cooling.',
#   'other'),
#  ('My car makes a weird whirring sound every time I start my car starts.',
#   'starter'),
#  ('I hear a grinding noise coming from somewhere in the front.', 'other'),
#  ('Car does not turn over.', 'starter'),
#  ("The car won't shift out of the car.", 'other'),
#  ('I think my car is leaning on left', 'other'),
#  ('The pedal feels squishy and pulses when I try to brake again.', 'brakes'),
#  ('I keep driving past my driveway because the car does not stop', 'brakes'),
#  ('Then I have to press the brakes disengage.', 'brakes'),
#  ('When I put the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ("super frustrating every time I start my car but it doesn't work.",
#   'starter'),
#  ('It takes a long time to start, and if I push the key and hear funny sounds but nothing happens.',
#   'starter'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('My tire keeps going flat.', 'other'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ("There isn't an immediate response.", 'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('It takes a long time before finally engaging and actually turning on.',
#   'starter'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('68F', 'other'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('But the car does not work, you pull the window up, it goes all the way up and then down.',
#   'other'),
#  ('I try to start the engine doesn’t power up', 'starter'),
#  ('There is a lag when I manually check it, it is fine.', 'other'),
#  ('It makes a grinding sound for a few seconds and then nothing happens.',
#   'starter'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ("It won't start again.", 'starter'),
#  ('I turn the key in it makes a grinding noise too.', 'starter'),
#  ('When I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ('The car make some squeaking noises when I press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ("My window won't roll up.", 'other'),
#  ("Where's the place, where I need to insert my key to start the ignition?",
#   'starter'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('It seems like I have to brake the car', 'brakes'),
#  ('There is a bit short these days.', 'other'),
#  ("The HVAC system is broken in the back of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('My car is leaning on left', 'other'),
#  ('It makes a sputtering noise and does not turn over.', 'starter'),
#  ('It sputters for a while and never turns over.', 'starter'),
#  ('There is a bit short these days.', 'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('The car pulls to the left.', 'other'),
#  ('The pedal feels squishy and pulses when I try to stop when I press on the brake pedal.',
#   'brakes'),
#  ("I can't put gas in my car", 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('Sometimes when I try to stop', 'brakes'),
#  ('Metallic scraping or grinding noise', 'brakes'),
#  ('When I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('My car is leaning on left', 'other'),
#  ('My car is leaning on left', 'other'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('Steering wheel shakes uncontrollably when I manually check it, it is fine.',
#   'other'),
#  ("I tried starting my car but it doesn't work.", 'starter'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('I came out from work at the end of the day and the car doesnt start.',
#   'starter'),
#  ('my brakes make a terrible sound when stopping.', 'brakes'),
#  ("the flux capacitor is misfiring and I don't get it.", 'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ("I can't put gas in my steering wheel.", 'other'),
#  ('I keep driving past my driveway because the car made horrible grinding noises.',
#   'brakes'),
#  ('Usefulness is vanishing...', 'other'),
#  ('I have to press the ignition button at least twice before my car it just stops again, what is wrong!',
#   'starter'),
#  ('my car does not stop', 'brakes'),
#  ('When I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('I try to start the car, it spits and sputters for a while and never turns over.',
#   'starter'),
#  ('I was working on the freeway.', 'other'),
#  ('It takes a long time to start, and if I push the key and hear funny sounds but nothing happens.',
#   'starter'),
#  ('That is all', 'other'),
#  ('The car pulls to the left.', 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('I came out from work at the end of the day and the car doesnt start.',
#   'starter'),
#  ('Alternator is faulty', 'starter'),
#  ("The gas door won't open.", 'other'),
#  ('Rear right tail light is out.', 'other'),
#  ('I try to start the ignition?', 'starter'),
#  ('Car dies when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ('It seems like I have to press the brakes disengage.', 'brakes'),
#  ('I turn the key, nothing happens.', 'other'),
#  ('Customer states breaks make a squeaking noise whenever I try to stop',
#   'brakes'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ("My window won't roll up.", 'other'),
#  ('The oil change has been performed.', 'other'),
#  ('When I try to start the engine unless you hit the starter with a hammer.',
#   'starter'),
#  ('Have to cycle the ignition button at least twice before my car starts.',
#   'starter'),
# ...
#   'starter'),
#  ('Usefulness is vanishing...', 'other'),
#  ('The oil change has been performed.', 'other'),
#  ("Car dies when I stop at a light or stop sign and then won't start the ignition?",
#   'starter'),
#  ('Everything seems to be wearing down at different rates.', 'other'),
#  ("My window won't roll up.", 'other'),
#  ('Please help ASAP!', 'starter'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ("I'm on the side of the car.", 'other'),
#  ('While driving I hear lot of grinding and scraping noises when I try to stop the car.',
#   'brakes'),
#  ("Where's the place, where I need to insert my key to start the ignition?",
#   'starter'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('68F', 'other'),
#  ('The left rear window only rolls down but does not roll back up.', 'other'),
#  ("the privacy glass between my driver and my seating area doesn't work",
#   'other'),
#  ('Not so much a grinding noise', 'brakes'),
#  ('I try to start it.', 'starter'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('The paint on the road', 'other'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ("It makes a grinding sound for a few seconds and then won't start the ignition?",
#   'starter'),
#  ('The brake squeak and any time the slightest pressure is applied to the brake pedal.',
#   'brakes'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('The car make some squeaking noises when I push hard on the brakes.',
#   'brakes'),
#  ('When I turn the key in it makes a grinding sound for a while and never turns over.',
#   'starter'),
#  ('There is a lag when I open my rear trunk', 'other'),
#  ('When I turn the key and nothing happens', 'starter'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ('I have replaced the battery since the lights would come one and the car would not start.',
#   'starter'),
#  ('Car takes too long to stop when I press down on the brake pedal', 'brakes'),
#  ('68F', 'other'),
#  ('The warning indicator light is out.', 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('my brakes make a deep grinding metal sound', 'brakes'),
#  ('windshield wipers', 'other'),
#  ('I tried starting my car starts.', 'starter'),
#  ('The car is now a pile of ashes.', 'other'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('my brakes make a terrible sound when stopping.', 'brakes'),
#  ("I'm hearing a noise and feeling a vibration when I go over a bump.",
#   'other'),
#  ("My window won't roll up.", 'other'),
#  ('My car is leaning on left', 'other'),
#  ("I'm hearing a noise and feeling a vibration when I accelerate above 60 mph",
#   'other'),
#  ('When I put the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('The warning indicator light is out.', 'other'),
#  ('While driving I hear lot of grinding and scraping noises when I press the brakes disengage.',
#   'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('The driver side window auto function does not roll back up.', 'other'),
#  ('It makes a sputtering noise and does not start.', 'starter'),
#  ('68F', 'other'),
#  ('My battery keeps dying.', 'other'),
#  ('I hear a rattling noise when I turn the key, nothing happens.', 'other'),
#  ('I have some noise when i drive it above 60 mph.', 'other'),
#  ('Cannot get the car doesnt start.', 'starter'),
#  ('The paint on the freeway.', 'other'),
#  ('The other 3 tires report normally.', 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ("The gas door won't open, and I'm all out of park.", 'other'),
#  ('When I tried to drive, the car', 'brakes'),
#  ('Just that odd clicking noise....', 'starter'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('And the brake pedal.', 'brakes'),
#  ('I think my alignment is bad.', 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down on the brakes.',
#   'brakes'),
#  ('My car is very unsafe.', 'other'),
#  ('The HVAC system is broken in the back of the car.', 'other'),
#  ('The other 3 tires report normally.', 'other'),
#  ('If I try to set it at anything other than MAX COOL, it defaults to full blast cooling.',
#   'other'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('It makes a grinding sound for a while and never turns over.', 'starter'),
#  ('my brakes make a squeaking noise whenever I try to brake again.', 'brakes'),
#  ('Car does not turn over.', 'starter'),
#  ('my lights do not work', 'other'),
#  ('Rear right tail light is out.', 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ("I can't put gas in my steering wheel.", 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('I can hear the starter firing but the car starts on the the fourth time.',
#   'starter'),
#  ("That's all good.", 'other'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('That is all', 'other'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('Metallic scraping or grinding noise', 'brakes'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ("My window won't roll up.", 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('Car takes too long to stop', 'brakes'),
#  ('super frustrating every time I start my car it just stops again, what is wrong!',
#   'starter'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('The HVAC system is broken in the front.', 'other'),
#  ('The car is making a clicking noise.', 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ('The car pulls to the left.', 'other'),
#  ('Car takes too long to stop', 'brakes'),
#  ('When I tried to drive, the car refuses to stop and sometimes very bumpy.',
#   'brakes'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('I try to start the engine only to find that the dashboard lights up, but the engine doesn’t power up',
#   'starter'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('There is a light that came on that looks to be working.', 'other'),
#  ('My battery keeps dying.', 'other'),
#  ("I can't open the damn door to my previous display which is very unsafe.",
#   'other'),
#  ("I can't open the damn door to my car if the control says, eg.", 'other'),
#  ("AC doesn't work well.", 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('Sometimes the car to turn over.', 'starter'),
#  ('Car takes too long to stop and sometimes very bumpy.', 'brakes'),
#  ('Not so much a grinding noise', 'brakes'),
#  ('The paint on the menu to return to my car is making a clicking noise.',
#   'other'),
#  ('My car does not turn over', 'starter'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('my lights do not work', 'other'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('When I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ('Brake pedal vibrates', 'brakes'),
#  ('There is a light that came on that looks to be wearing down at different rates.',
#   'other'),
#  ('Not so much a grinding noise', 'brakes'),
#  ('It seems like I have to brake the car refuses to stop the car.', 'brakes'),
#  ('When I tried to drive, the car', 'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ("My air conditioning doesn't seem to be wearing down at different rates.",
#   'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down on the brake pedal.',
#   'brakes'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('I was working on the left door is scratched.', 'other'),
#  ('Car makes a grinding noise and brakes disengage', 'brakes'),
#  ('car makes grinding noise', 'brakes'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('Usefulness is vanishing...', 'other'),
#  ('Not so much a grinding noise when breaking.', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('Car takes too long to stop', 'brakes'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('The car is making a clicking noise.', 'other'),
#  ('The warning indicator light is out.', 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ('Have to cycle the ignition three times before the car to turn over.',
#   'starter'),
#  ('Please help ASAP!', 'starter'),
#  ('Car won’t stop quickly', 'brakes'),
#  ("There isn't an immediate response.", 'other'),
#  ('The car pulls to the left.', 'other'),
#  ('68F', 'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('My car sounds like its 20 years old when I try to stop and sometimes very bumpy.',
#   'brakes'),
#  ("That's all good.", 'other'),
#  ('Steering wheel shakes when running at speed', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('Car takes too long to stop', 'brakes'),
#  ('my lights do not work', 'other'),
#  ('Brake pedal vibrates', 'brakes'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('Car does not start.', 'starter'),
#  ('The paint on the left door is scratched.', 'other'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ('When I try to start the engine unless you hit the starter firing but the car doesnt start.',
#   'starter'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('Car makes a grinding noise', 'brakes'),
#  ('The car is talking to me through the radio and asking me if I know where the All Spark is hidden',
#   'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('My car makes a weird whirring sound every time I try to start it.',
#   'starter'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('I have some noise when I open my rear trunk', 'other'),
#  ("Everything seems to be working ok, but that sound wasn't there when I bought the car.",
#   'other'),
#  ("It won't start again.", 'starter'),
#  ('The driver side window auto function does not roll back up.', 'other'),
#  ('I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Alternator is faulty', 'starter'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Then I have to press the brake pedal vibrates', 'brakes'),
#  ('I turn the key and nothing happens', 'starter'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('I have the button pushed in and the air bag or seat belt.', 'other'),
#  ('While driving I hear lot of grinding and scraping noises when I push hard on the brakes.',
#   'brakes'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('Steering wheel shakes when running at speed', 'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('And the brake pedal vibrates', 'brakes'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('I try to start it.', 'starter'),
#  ('It seems like I have to press the brake pedal.', 'brakes'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ("Where's the place, where I need to insert my key to start it.", 'starter'),
#  ('It then takes several clicks on the left door is scratched.', 'other'),
#  ('My battery keeps dying.', 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ("That's all good.", 'other'),
#  ("Starter makes clicking noise, won't start again.", 'starter'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('I think my alignment is bad.', 'other'),
#  ('The left rear window only rolls down but does not roll back up.', 'other'),
#  ('car makes grinding noise', 'brakes'),
#  ('my lights do not work', 'other'),
#  ('Then I have to press the brakes', 'brakes'),
#  ('I have the button pushed in and the batteries just keep dying after about a week.',
#   'other'),
#  ('There is a bit short these days.', 'other'),
#  ("The car won't start!", 'other'),
#  ('Alternator is faulty', 'starter'),
#  ('Everything seems to be working.', 'other'),
#  ('When coming to a complete stop.', 'brakes'),
#  ('the privacy glass between my driver and my tires seem to be wearing down at different rates.',
#   'other'),
#  ("The car won't turn on, but it kind of won't stop either.", 'other'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ('Cannot get the car to turn over.', 'starter'),
#  ('When I tried to drive, the car made horrible grinding noises.', 'brakes'),
#  ('This is the third one, and I hear a grinding noise coming from somewhere in the car.',
#   'other'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('my brakes make a squeaking noise whenever I try to stop', 'brakes'),
#  ('Car does not turn over.', 'starter'),
#  ('I have replaced the battery since the lights would come one and the car would not start.',
#   'starter'),
#  ('The warning indicator light is out.', 'other'),
#  ('It then takes several clicks on the freeway.', 'other'),
#  ('My car does not turn over', 'starter'),
#  ('my car does slow, but it takes a long time to come to a complete stop.',
#   'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('Then I have to brake the car comes to a stop at a stop at a stop light, I press down',
#   'brakes'),
#  ('My car is now a pile of ashes.', 'other'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('my lights do not work', 'other'),
#  ('When it rains, the car is making a clicking noise.', 'other'),
#  ("I'm hearing a noise and feeling a vibration when I accelerate above 60 mph",
#   'other'),
#  ('I think my car if the control says, eg.', 'other'),
#  ("When I drive, I feel like the car won't start!", 'other'),
#  ("I tried starting my car but it doesn't work.", 'starter'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('I think my alignment is bad.', 'other'),
#  ('That is all', 'other'),
#  ("It won't go, but it won't go up at all!", 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('It takes a long time before finally engaging and actually turning on.',
#   'starter'),
#  ('It is very unpleasant.', 'brakes'),
#  ('I think my car', 'other'),
#  ('I press down on the brake and the car does slow, but it takes more force to stop',
#   'brakes'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('The paint on the left door is scratched.', 'other'),
#  ('the privacy glass between my driver and my tires seem to be working.',
#   'other')]

# %%
len(sentence_tuples)
# Out:
# 1000

# %% [markdown]
# We can save these new issues and responses to file, and we will use this file later to train our model.

# %%
# Write to csv file
with open('dataset/testdata1.csv', 'w') as file:
    writer = csv.writer(file, delimiter=',', lineterminator='\n')
    writer.writerows(sentence_tuples)

# %% [markdown]
# At this point we have created a new data set, and we can transform this data and train a classification model.
#
# Let's head to notebook [01-Create-Claims-Classification.ipynb](01-Create-Claims-Classification.ipynb), where we process the data and train a classifier.
